# %% [markdown]
# # **🚀 Пакеты в Julia. Урок Седьмой.**
#
# <br>
#
# ## **📌 Темы:**
#
# 1. **Экосистема Julia - Гибкость и интеграция с другими языками.**
#
# 2. **Что такое REPL в Julia?**
#
# 3. **Менеджер пакетов в Julia `Pkg` .**
#
# 4. **Управление зависимостями и виртуальным окружением в Julia.**
#
# <br>
#
# ---
#
#  <br>
#
# Один из ключевых аспектов языка программирования **Julia** - его мощная и гибкая система пакетов. В настоящее время существует более **10.000 зарегистрированных пакетов** доступных на [Julia Packages](https://julialang.org/packages/), которые охватывают широкий спектр задач: от численных вычислений и машинного обучения до визуализации данных, работы с базами данных и веб-разработки. Благодаря этому Julia продолжает набирать популярность среди ученых, инженеров, аналитиков данных и разработчиков.
#
# <br>
#
# ### **1️⃣ Экосистема Julia - Гибкость и интеграция с другими языками.**
#
# Хотя экосистема Julia все еще развивается и уступает по количеству пакетов таким языкам, как Python или R, у нее есть важное преимущество: **отличная интеграция с другими языками программирования**. В Julia реализованы первоклассные интерфейсы для вызова функций из внешних языков, что позволяет легко использовать уже существующие решения. Например:
#
# - **PyCall** — позволяет вызывать функции и библиотеки из Python напрямую в Julia. Это удобно, если вам нужны инструменты из экосистемы NumPy, Pandas, TensorFlow и других.
#
# - **RCall** — аналогичный пакет для работы с R, который позволяет использовать мощные инструменты статистического анализа и визуализации.
#
# - **CxxWrap** и **Clang.jl** — обеспечивают взаимодействие с C++.
#
# - **JavaCall** — предоставляет возможность вызова функций Java.
#
# - **FortranCall** — помогает интегрировать код на Fortran.
#
# 💡 Это означает, что даже если нужного вам пакета нет в Julia, вы всегда можете воспользоваться решениями из других языков, не теряя производительности и удобства.
#
# <br>
#
# #### 📌 Преимущества пакетов в Julia
#
# 1. **Высокая производительность** — Julia разработана с учетом скорости выполнения, и это распространяется на пакеты. Большинство из них оптимизировано для работы без накладных расходов, типичных для интерпретируемых языков.
# 2. **Простота установки и использования** — управление пакетами осуществляется через встроенный пакетный менеджер `Pkg`, который позволяет легко устанавливать, обновлять и удалять зависимости.
# 3. **Развитие и поддержка** — активное сообщество и постоянное развитие языка делают экосистему Julia все более мощной.
# 4. **Совместимость с другими языками** — возможность использовать Python, R, C++ и другие технологии делает Julia гибким инструментом.
#
# ### Где найти пакеты?
#
# Если вы хотите ознакомиться со всеми доступными пакетами, вы можете посетить **официальный каталог пакетов** Julia:
#
# 🔗 [https://julialang.org/packages/](https://julialang.org/packages/)
#
# Здесь представлены все доступные библиотеки, их описания, документация и инструкции по установке.
#
# <br>
#
# В следующих разделах мы разберем **REPL**, как устанавливать, загружать и использовать пакеты в Julia, а также познакомимся с некоторыми из самых популярных библиотек. 🚀

# %% [markdown]
# <br>
#
# ---
#
# <br>
#
# ### **2️⃣ Что такое REPL в Julia?**

# %% [markdown]
# <br>
#
# #### 📌 **Определение и назначение**
#
# REPL (**Read-Eval-Print Loop**, или «Читай-Выполни-Печатай-Цикл») — это **интерактивная оболочка Julia**, которая позволяет вводить команды и мгновенно получать результаты. Это мощный инструмент для тестирования кода, выполнения вычислений и работы с пакетами.
#
# Julia автоматически открывает REPL при запуске без аргументов в командной строке:
#
# ```sh
# $> julia
# ```

# %% [markdown]
# После этого появляется приглашение (`julia>`), где можно вводить выражения Julia.
# ```sh
# julia>_
# ```

# %% [markdown]
# #### **Чем же так удобен REPL ?**
#
# - Позволяет **быстро тестировать код** без необходимости писать и запускать отдельные файлы.
#
# - Поддерживает **режим работы с пакетами** и **специальные команды**.
#
# - Включает **различные режимы ввода**, которые ускоряют работу.
#
# <br>

# %% [markdown]
# ### 📌 **Основные режимы REPL в Julia**
#
# В Julia REPL есть **четыре режима**, переключение между которыми осуществляется одной клавишей:

# %% [markdown]
# #### **1️. Обычный режим (Julia Mode)**
# По умолчанию REPL работает в режиме Julia. В нем можно вводить и выполнять код:

# %% [markdown]
# ```julia
#
# julia> 2 + 3
# 5
#
# julia> sqrt(16)
# 4.0
# ```

# %% [markdown]
# - При необходимости можно объявлять переменные и писать многострочные выражения:

# %% [markdown]
# ```julia
# julia> x = 10
# 10
#
# julia> y = 5
# 5
#
# julia> x + y
# 15
# ```

# %% [markdown]
# <br>
#
# #### **2️. Режим управления пакетами (Pkg Mode)**
# Менеджер пакетов `Pkg` встроен в REPL и вызывается клавишей `]`:
#
# ```sh
# julia> ]
# (@v1.9) pkg> add Plots
# ```

# %% [markdown]
# В этом режиме можно:
#
# - Устанавливать пакеты: `add Plots`
#
# - Обновлять пакеты: `update`
#
# - Удалять пакеты: `remove Plots`
#
# - Смотреть список установленных пакетов: `status`
#
# - Создавать виртуальные окружения: `activate .`
#
# ***💡 Чтобы выйти из режима пакетов, просто нажмите:*** **Backspace (←) или Ctrl + C**.
#
# <br>

# %% [markdown]
# #### **3️. Режим оболочки (Shell Mode)**
#
# Позволяет выполнять команды операционной системы. Включается символом `;`:
#
# ```sh
#
# julia> ;ls  # В Linux/macOS
#
# julia> ;dir  # В Windows
# ```
#
# Примеры использования:
#
# - `;pwd` — узнать текущую директорию
#
# - `;cd my_folder` — сменить каталог
#
# - `;echo "Hello, Julia!"` — вывести сообщение в терминал
#
# <br>

# %% [markdown]
# #### **4️. Режим помощи (Help Mode)**
# Этот режим вызывается клавишей `?`. Он используется для просмотра документации по функциям и пакетам:
#
# ```sh
# julia> ?
# help?> sqrt
#
# ```
#
# **Вывод:**
#
# ```sh
# search: sqrt isqrt sort sort! sprint Cshort stat cbrt struct
#
#   sqrt(x)
#
#   Return \sqrt{x}.
#
#   Throws DomainError for negative Real arguments. Use complex negative arguments instead. Note that sqrt has a branch
#   cut along the negative real axis.
#
#   The prefix operator √ is equivalent to sqrt.
#
#   See also: hypot.
#
#   Examples
#   ≡≡≡≡≡≡≡≡
#   ...
#
#
# ```
#
# **💡 Можно использовать `?` и получить информацию о любой функции Julia, чтобы узнать о ней больше и посмотреть примеры.**
#
# **Пример:**
#
# ```sh
# julia> ?
# help?> println
#
# ```
#
# **Вывод:**
#
# ```sh
# search: println print sprint pointer printstyled
#
#   println([io::IO], xs...)
#
#   Print (using print) xs to io followed by a newline. If io is not supplied, prints to the default output stream
#   stdout.
#
#   See also printstyled to add colors etc.
#
#   Examples
#   ≡≡≡≡≡≡≡≡
#
#   julia> println("Hello, world")
#   Hello, world
#
#   julia> io = IOBuffer();
#
#   julia> println(io, "Hello", ',', " world.")
#
#   julia> String(take!(io))
#   "Hello, world.\n"
#
# ```

# %% [markdown]
# <br>
#
# ### 📌 **Дополнительные возможности REPL :**
#
# #### 1. **Автодополнение**
#
# Нажмите **Tab**, чтобы автоматически дополнить команды и переменные.
#
# ```sh
# julia> sq[TAB]
# sqrt  sqrt1p  sqrtpi
# ```
#
# <br>
#
# #### 2. **Использование многосрочных выражений**
#
# Вводя выражение на нескольких строках, просто продолжайте писать, и REPL поймет, что код не завершен:
#
# ```sh
# julia> function add(a, b)
#            return a + b
#        end
# ```
#
# <br>
#
# ### 📌 **Выход из REPL**
#
# Чтобы выйти из Julia, используйте:
#
# - **`exit()`** или **`Ctrl + D`**
#
# - **`quit()`** (в новых версиях)
#
# <br>
#
#
#
# #### 😺 **Выводы:**
#
# REPL в Julia — это мощный инструмент, который облегчает работу с языком.
#
# Он поддерживает:
#
# ✅ Обычный режим для написания кода
#
# ✅ Режим работы с пакетами (`]`)
#
# ✅ Режим командной строки (`;`)
#
# ✅ Режим документации (`?`)
#
#
# Далее мы разберемся **как использовать менеджер пакетов Julia `Pkg`** для установки и управления библиотеками. 🚀
#
# <br>
#
# ---
#
# <br>

# %% [markdown]
# ### **3️⃣ Менеджер пакетов в Julia `Pkg` .**
#
# Julia обладает **встроенной системой управления пакетами** — `Pkg`, которая позволяет легко устанавливать, обновлять, удалять и управлять зависимостями. Он аналогичен `pip` в Python или `npm` в JavaScript, но разработан специально для нужд экосистемы Julia.
#
# <br>
#
# #### 📌 **Установка пакетов.**
#
# При первом использовании пакета в данной установке Julia вам необходимо явно добавить его с помощью менеджера пакетов. Это можно сделать несколькими способами.
#
# <br>
#
# #### 1. Установка через REPL (интерактивную консоль Julia).
#
# Julia поддерживает **специальный режим работы с пакетами**. Чтобы открыть его, нужно нажать `]` в REPL. В этом режиме доступны команды для установки и управления пакетами.
#
# Например, чтобы установить пакет `Plots` для визуализации данных, выполните:
#
# ```sh
# julia> ]
#
# (@v1.11) pkg> add Plots
# ```
# <br>
# Аналогично можно установить несколько пакетов одновременно:
#
# ```sh
# julia> ]
#
# (@v1.11) pkg> add DataFrames CSV Statistics
# ```
#
# <br>

# %% [markdown]
# #### 2. Установка пакета в обычном режиме Julia.
#
# Если вы работаете в скрипте или ноутбуке, можно использовать функцию `Pkg.add`:

# %%
using Pkg
Pkg.add("Plots")
# Out:
#    Resolving package versions...
#    Installed MarchingCubes ──── v0.1.11
#    Installed VersionParsing ─── v1.3.0
#    Installed StaticArraysCore ─ v1.4.3
#    Installed Conda ──────────── v1.10.2
#    Installed PyCall ─────────── v1.96.4
#    Installed StaticArrays ───── v1.9.13
#    Installed BenchmarkTools ─── v1.6.0
#    Installed Example ────────── v0.5.5
#    Installed UnicodePlots ───── v3.7.2
#     Updating `C:\Users\Siergej Sobolewski\Kursy Cartesian School\Julia\Introduction-to-Julia-main\Introduction-to-Julia-main\Project.toml`
#   [6e4b80f9] + BenchmarkTools v1.6.0
#   [5ae59095] + Colors v0.13.0
#   [8f4d0f93] + Conda v1.10.2
#   [7876af07] + Example v0.5.5
#   [91a5bcdd] + Plots v1.40.9
#   [438e738f] + PyCall v1.96.4
#   [b8865327] + UnicodePlots v3.7.2
#     Updating `C:\Users\Siergej Sobolewski\Kursy Cartesian School\Julia\Introduction-to-Julia-main\Introduction-to-Julia-main\Manifest.toml`
#   [66dad0bd] + AliasTables v1.1.3
#   [6e4b80f9] + BenchmarkTools v1.6.0
#   [d1d4a3ce] + BitFlags v0.1.9
#   [944b1d66] + CodecZlib v0.7.8
#   [35d6a980] + ColorSchemes v3.29.0
#   [3da002f7] + ColorTypes v0.12.0
#   [c3611d14] + ColorVectorSpace v0.11.0
#   [5ae59095] + Colors v0.13.0
#   [34da2185] + Compat v4.16.0
#   [f0e56b4a] + ConcurrentUtilities v2.5.0
#   [8f4d0f93] + Conda v1.10.2
#   [d38c429a] + Contour v0.6.3
#   [a8cc5b0e] + Crayons v4.1.1
#   [9a962f9c] + DataAPI v1.16.0
#   [864edb3b] + DataStructures v0.18.20
#   [8bb1440f] + DelimitedFiles v1.9.1
#   [ffbed154] + DocStringExtensions v0.9.3
#   [7876af07] + Example v0.5.5
#   [460bff9d] + ExceptionUnwrapping v0.1.11
#   [c87230d0] + FFMPEG v0.4.2
#   [53c48c17] + FixedPointNumbers v0.8.5
#   [1fa38f19] + Format v1.3.7
#   [28b8d3ca] + GR v0.73.13
#   [42e2da0e] + Grisu v1.0.2
#   [cd3eb016] + HTTP v1.10.15
#   [92d709cd] + IrrationalConstants v0.2.4
#   [1019f520] + JLFzf v0.1.9
#   [692b3bcd] + JLLWrappers v1.7.0
#   [682c06a0] + JSON v0.21.4
#   [b964fa9f] + LaTeXStrings v1.4.0
#   [23fbe1c1] + Latexify v0.16.6
#   [2ab3a3ac] + LogExpFunctions v0.3.29
#   [e6f89c97] + LoggingExtras v1.1.0
#   [1914dd2f] + MacroTools v0.5.15
#   [299715c1] + MarchingCubes v0.1.11
#   [739be429] + MbedTLS v1.1.9
#   [442fdcdd] + Measures v0.3.2
#   [e1d29d7a] + Missings v1.2.0
#   [77ba4419] + NaNMath v1.1.2
#   [4d8831e6] + OpenSSL v1.4.3
#   [bac558e1] + OrderedCollections v1.8.0
#   [69de0a69] + Parsers v2.8.1
#   [b98c9c47] + Pipe v1.3.0
#   [ccf2f8ad] + PlotThemes v3.3.0
#   [995b91a9] + PlotUtils v1.4.3
#   [91a5bcdd] + Plots v1.40.9
#   [aea7be01] + PrecompileTools v1.2.1
#   [21216c6a] + Preferences v1.4.3
#   [43287f4e] + PtrArrays v1.3.0
#   [438e738f] + PyCall v1.96.4
#   [3cdcf5f2] + RecipesBase v1.3.4
#   [01d81517] + RecipesPipeline v0.6.12
#   [189a3867] + Reexport v1.2.2
#   [05181044] + RelocatableFolders v1.0.1
#   [ae029012] + Requires v1.3.1
#   [6c6a2e73] + Scratch v1.2.1
#   [992d4aef] + Showoff v1.0.3
#   [777ac1f9] + SimpleBufferStream v1.2.0
#   [a2af1166] + SortingAlgorithms v1.2.1
#   [860ef19b] + StableRNGs v1.0.2
#   [90137ffa] + StaticArrays v1.9.13
#   [1e83bf80] + StaticArraysCore v1.4.3
#   [10745b16] + Statistics v1.11.1
#   [82ae8749] + StatsAPI v1.7.0
#   [2913bbd2] + StatsBase v0.34.4
#   [62fd8b95] + TensorCore v0.1.1
#   [3bb67fe8] + TranscodingStreams v0.11.3
#   [5c2747f8] + URIs v1.5.1
#   [1cfade01] + UnicodeFun v0.4.1
#   [b8865327] + UnicodePlots v3.7.2
#   [1986cc42] + Unitful v1.22.0
#   [45397f5d] + UnitfulLatexify v1.6.4
#   [41fe7b60] + Unzip v0.2.0
#   [81def892] + VersionParsing v1.3.0
#   [6e34b625] + Bzip2_jll v1.0.9+0
#   [83423d85] + Cairo_jll v1.18.2+1
#   [ee1fde0b] + Dbus_jll v1.14.10+0
#   [2702e6a9] + EpollShim_jll v0.0.20230411+1
#   [2e619515] + Expat_jll v2.6.5+0
# ⌅ [b22a6f82] + FFMPEG_jll v4.4.4+1
#   [a3f928ae] + Fontconfig_jll v2.15.0+0
#   [d7e528f0] + FreeType2_jll v2.13.3+1
#   [559328eb] + FriBidi_jll v1.0.16+0
#   [0656b61e] + GLFW_jll v3.4.0+2
#   [d2c73de3] + GR_jll v0.73.13+0
#   [78b55507] + Gettext_jll v0.21.0+0
#   [7746bdde] + Glib_jll v2.82.4+0
#   [3b182d85] + Graphite2_jll v1.3.14+1
#   [2e76f6c2] + HarfBuzz_jll v8.5.0+0
#   [aacddb02] + JpegTurbo_jll v3.1.1+0
#   [c1c5ebd0] + LAME_jll v3.100.2+0
#   [88015f11] + LERC_jll v4.0.1+0
#   [1d63c593] + LLVMOpenMP_jll v18.1.7+0
#   [dd4b983a] + LZO_jll v2.10.3+0
# ⌅ [e9f186c6] + Libffi_jll v3.2.2+2
#   [d4300ac3] + Libgcrypt_jll v1.11.0+0
#   [7e76a0d4] + Libglvnd_jll v1.7.0+0
#   [7add5ba3] + Libgpg_error_jll v1.51.1+0
#   [94ce4f54] + Libiconv_jll v1.18.0+0
#   [4b2f31a3] + Libmount_jll v2.40.3+0
#   [89763e89] + Libtiff_jll v4.7.1+0
#   [38a345b3] + Libuuid_jll v2.40.3+0
#   [e7412a2a] + Ogg_jll v1.3.5+1
#   [458c3c95] + OpenSSL_jll v3.0.16+0
#   [91d4177d] + Opus_jll v1.3.3+0
#   [36c8627f] + Pango_jll v1.56.1+0
# ⌅ [30392449] + Pixman_jll v0.43.4+0
# ⌅ [c0090381] + Qt6Base_jll v6.7.1+1
# ⌅ [629bc702] + Qt6Declarative_jll v6.7.1+2
# ⌅ [ce943373] + Qt6ShaderTools_jll v6.7.1+1
# ⌃ [e99dba38] + Qt6Wayland_jll v6.7.1+1
#   [a44049a8] + Vulkan_Loader_jll v1.3.243+0
#   [a2964d1f] + Wayland_jll v1.21.0+2
#   [2381bf8a] + Wayland_protocols_jll v1.36.0+0
#   [02c8fc9c] + XML2_jll v2.13.6+1
#   [aed1982a] + XSLT_jll v1.1.42+0
#   [ffd25f8a] + XZ_jll v5.6.4+1
#   [f67eecfb] + Xorg_libICE_jll v1.1.1+0
#   [c834827a] + Xorg_libSM_jll v1.2.4+0
#   [4f6342f7] + Xorg_libX11_jll v1.8.6+3
#   [0c0b7dd1] + Xorg_libXau_jll v1.0.12+0
#   [935fb764] + Xorg_libXcursor_jll v1.2.3+0
#   [a3789734] + Xorg_libXdmcp_jll v1.1.5+0
#   [1082639a] + Xorg_libXext_jll v1.3.6+3
#   [d091e8ba] + Xorg_libXfixes_jll v6.0.0+0
#   [a51aa0fd] + Xorg_libXi_jll v1.8.2+0
#   [d1454406] + Xorg_libXinerama_jll v1.1.5+0
#   [ec84b674] + Xorg_libXrandr_jll v1.5.4+0
#   [ea2f1a96] + Xorg_libXrender_jll v0.9.11+1
#   [14d82f49] + Xorg_libpthread_stubs_jll v0.1.2+0
#   [c7cfdc94] + Xorg_libxcb_jll v1.17.0+3
#   [cc61e674] + Xorg_libxkbfile_jll v1.1.2+1
#   [e920d4aa] + Xorg_xcb_util_cursor_jll v0.1.4+0
#   [12413925] + Xorg_xcb_util_image_jll v0.4.0+1
#   [2def613f] + Xorg_xcb_util_jll v0.4.0+1
#   [975044d2] + Xorg_xcb_util_keysyms_jll v0.4.0+1
#   [0d47668e] + Xorg_xcb_util_renderutil_jll v0.3.9+1
#   [c22f9ab0] + Xorg_xcb_util_wm_jll v0.4.1+1
#   [35661453] + Xorg_xkbcomp_jll v1.4.6+1
#   [33bec58e] + Xorg_xkeyboard_config_jll v2.39.0+0
#   [c5fb5394] + Xorg_xtrans_jll v1.5.1+0
#   [3161d3a3] + Zstd_jll v1.5.7+1
#   [35ca27e7] + eudev_jll v3.2.9+0
#   [214eeab7] + fzf_jll v0.56.3+0
#   [1a1c6b14] + gperf_jll v3.1.1+1
#   [a4ae2306] + libaom_jll v3.11.0+0
#   [0ac62f75] + libass_jll v0.15.2+0
#   [1183f4f0] + libdecor_jll v0.2.2+0
#   [2db6ffa8] + libevdev_jll v1.11.0+0
#   [f638f0a6] + libfdk_aac_jll v2.0.3+0
#   [36db933b] + libinput_jll v1.18.0+0
#   [b53b4c65] + libpng_jll v1.6.46+0
#   [f27f6e37] + libvorbis_jll v1.3.7+2
#   [009596ad] + mtdev_jll v1.1.6+0
# ⌅ [1270edf5] + x264_jll v2021.5.5+0
# ⌅ [dfaa095f] + x265_jll v3.5.0+0
#   [d8fb68d0] + xkbcommon_jll v1.4.1+2
#   [0dad84c5] + ArgTools v1.1.2
#   [56f22d72] + Artifacts v1.11.0
#   [2a0f44e3] + Base64 v1.11.0
#   [ade2ca70] + Dates v1.11.0
#   [f43a241f] + Downloads v1.6.0
#   [7b1f6079] + FileWatching v1.11.0
#   [b77e0a4c] + InteractiveUtils v1.11.0
#   [b27032c2] + LibCURL v0.6.4
#   [76f85450] + LibGit2 v1.11.0
#   [8f399da3] + Libdl v1.11.0
#   [37e2e46d] + LinearAlgebra v1.11.0
#   [56ddb016] + Logging v1.11.0
#   [d6f4376e] + Markdown v1.11.0
#   [a63ad114] + Mmap v1.11.0
#   [ca575930] + NetworkOptions v1.2.0
#   [44cfe95a] + Pkg v1.11.0
#   [de0858da] + Printf v1.11.0
#   [9abbd945] + Profile v1.11.0
#   [3fa0cd96] + REPL v1.11.0
#   [9a3f8284] + Random v1.11.0
#   [ea8e919c] + SHA v0.7.0
#   [9e88b42a] + Serialization v1.11.0
#   [6462fe0b] + Sockets v1.11.0
#   [2f01184e] + SparseArrays v1.11.0
#   [f489334b] + StyledStrings v1.11.0
#   [fa267f1f] + TOML v1.0.3
#   [a4e569a6] + Tar v1.10.0
#   [8dfed614] + Test v1.11.0
#   [cf7118a7] + UUIDs v1.11.0
#   [4ec0a83e] + Unicode v1.11.0
#   [e66e0078] + CompilerSupportLibraries_jll v1.1.1+0
#   [deac9b47] + LibCURL_jll v8.6.0+0
#   [e37daf67] + LibGit2_jll v1.7.2+0
#   [29816b5a] + LibSSH2_jll v1.11.0+1
#   [c8ffd9c3] + MbedTLS_jll v2.28.6+0
#   [14a3606d] + MozillaCACerts_jll v2023.12.12
#   [4536629a] + OpenBLAS_jll v0.3.27+1
#   [05823500] + OpenLibm_jll v0.8.1+2
#   [efcefdf7] + PCRE2_jll v10.42.0+1
#   [bea87d4a] + SuiteSparse_jll v7.7.0+0
#   [83775a58] + Zlib_jll v1.2.13+1
#   [8e850b90] + libblastrampoline_jll v5.11.0+0
#   [8e850ede] + nghttp2_jll v1.59.0+0
#   [3f19e933] + p7zip_jll v17.4.0+2
#         Info Packages marked with ⌃ and ⌅ have new versions available. Those with ⌃ may be upgradable, but those with ⌅ are restricted by compatibility constraints from upgrading. To see why use `status --outdated -m`
#     Building Conda ─→ `C:\Users\Siergej Sobolewski\.julia\scratchspaces\44cfe95a-1eb2-52ea-b672-e2afdf69b78f\b19db3927f0db4151cb86d073689f2428e524576\build.log`
#     Building PyCall → `C:\Users\Siergej Sobolewski\.julia\scratchspaces\44cfe95a-1eb2-52ea-b672-e2afdf69b78f\9816a3826b0ebf49ab4926e2b18842ad8b5c8f04\build.log`
# Error building `PyCall`:
#
# Precompiling VersionParsing...
#
#    1418.3 ms  ✓ VersionParsing
#
#   1 dependency successfully precompiled in 1 seconds
#
# Precompiling Conda...
#
#   26070.6 ms  ✓ Parsers
#
#    2451.0 ms  ✓ JSON
#
#    1499.7 ms  ✓ Conda
#
#   3 dependencies successfully precompiled in 31 seconds. 19 already precompiled.
#
# ┌ Info: Using the Python distribution in the Conda package by default.
#
# └ To use a different Python version, set ENV["PYTHON"]="pythoncommand" and re-run Pkg.build("PyCall").
#
# ERROR: LoadError: Conda.jl cannot be installed to its default location C:\Users\Siergej Sobolewski\.julia\conda\3\x86_64
#
# as Miniconda does not support the installation to a directory with a space or a
#
# non-ASCII character on Windows. The work-around is to install Miniconda to a
#
# user-writable directory by setting the CONDA_JL_HOME environment variable. For
#
# example on Windows:
#
#
#
# ENV["CONDA_JL_HOME"] = raw"C:\Conda-Julia\3"
#
# using Pkg
#
# Pkg.build("Conda")
#
#
#
# The Julia session need to be restarted. More information is available at
#
# https://github.com/JuliaPy/Conda.jl.
#
#
#
# Stacktrace:
#
#  [1] error(s::String)
#
#    @ Base .\error.jl:35
#
#  [2] _install_conda(env::String, force::Bool)
#
#    @ Conda C:\Users\Siergej Sobolewski\.julia\packages\Conda\zReqD\src\Conda.jl:274
#
#  [3] _install_conda(env::String)
#
#    @ Conda C:\Users\Siergej Sobolewski\.julia\packages\Conda\zReqD\src\Conda.jl:270
#
#  [4] runconda(args::Cmd, env::String)
#
#    @ Conda C:\Users\Siergej Sobolewski\.julia\packages\Conda\zReqD\src\Conda.jl:180
#
#  [5] add(pkg::String, env::String; channel::String, satisfied_skip_solve::Bool, args::Cmd)
#
#    @ Conda C:\Users\Siergej Sobolewski\.julia\packages\Conda\zReqD\src\Conda.jl:343
#
#  [6] add
#
#    @ C:\Users\Siergej Sobolewski\.julia\packages\Conda\zReqD\src\Conda.jl:326 [inlined]
#
#  [7] top-level scope
#
#    @ C:\Users\Siergej Sobolewski\.julia\packages\PyCall\1gn3u\deps\build.jl:79
#
#  [8] include(fname::String)
#
#    @ Main .\sysimg.jl:38
#
#  [9] top-level scope
#
#    @ none:5
#
# in expression starting at C:\Users\Siergej Sobolewski\.julia\packages\PyCall\1gn3u\deps\build.jl:43
#
#
#
# Stacktrace:
#
#   [1] pkgerror(msg::String)
#
#     @ Pkg.Types C:\Users\Siergej Sobolewski\AppData\Local\Programs\Julia-1.11.3\share\julia\stdlib\v1.11\Pkg\src\Types.jl:68
#
#   [2] (::Pkg.Operations.var"#67#74"{Bool, Pkg.Types.Context, String, Pkg.Types.PackageSpec, String})()
#
#     @ Pkg.Operations C:\Users\Siergej Sobolewski\AppData\Local\Programs\Julia-1.11.3\share\julia\stdlib\v1.11\Pkg\src\Operations.jl:1191
#
#   [3] withenv(::Pkg.Operations.var"#67#74"{Bool, Pkg.Types.Context, String, Pkg.Types.PackageSpec, String}, ::Pair{String, String}, ::Vararg{Pair{String}})
#
#     @ Base .\env.jl:265
#
#   [4] (::Pkg.Operations.var"#118#123"{String, Pkg.Types.EnvCache, Bool, Bool, Bool, Pkg.Operations.var"#67#74"{Bool, Pkg.Types.Context, String, Pkg.Types.PackageSpec, String}, Pkg.Types.PackageSpec})()
#
#     @ Pkg.Operations C:\Users\Siergej Sobolewski\AppData\Local\Programs\Julia-1.11.3\share\julia\stdlib\v1.11\Pkg\src\Operations.jl:1927
#
#   [5] with_temp_env(fn::Pkg.Operations.var"#118#123"{String, Pkg.Types.EnvCache, Bool, Bool, Bool, Pkg.Operations.var"#67#74"{Bool, Pkg.Types.Context, String, Pkg.Types.PackageSpec, String}, Pkg.Types.PackageSpec}, temp_env::String)
#
#     @ Pkg.Operations C:\Users\Siergej Sobolewski\AppData\Local\Programs\Julia-1.11.3\share\julia\stdlib\v1.11\Pkg\src\Operations.jl:1785
#
#   [6] (::Pkg.Operations.var"#116#121"{Dict{String, Any}, Bool, Bool, Bool, Pkg.Operations.var"#67#74"{Bool, Pkg.Types.Context, String, Pkg.Types.PackageSpec, String}, Pkg.Types.Context, Pkg.Types.PackageSpec, String, String})(tmp::String)
#
#     @ Pkg.Operations C:\Users\Siergej Sobolewski\AppData\Local\Programs\Julia-1.11.3\share\julia\stdlib\v1.11\Pkg\src\Operations.jl:1894
#
#   [7] mktempdir(fn::Pkg.Operations.var"#116#121"{Dict{String, Any}, Bool, Bool, Bool, Pkg.Operations.var"#67#74"{Bool, Pkg.Types.Context, String, Pkg.Types.PackageSpec, String}, Pkg.Types.Context, Pkg.Types.PackageSpec, String, String}, parent::String; prefix::String)
#
#     @ Base.Filesystem .\file.jl:819
#
#   [8] mktempdir(fn::Function, parent::String)
#
#     @ Base.Filesystem .\file.jl:815
#
#   [9] mktempdir
#
#     @ .\file.jl:815 [inlined]
#
#  [10] #sandbox#115
#
#     @ C:\Users\Siergej Sobolewski\AppData\Local\Programs\Julia-1.11.3\share\julia\stdlib\v1.11\Pkg\src\Operations.jl:1841 [inlined]
#
#  [11] build_versions(ctx::Pkg.Types.Context, uuids::Set{Base.UUID}; verbose::Bool)
#
#     @ Pkg.Operations C:\Users\Siergej Sobolewski\AppData\Local\Programs\Julia-1.11.3\share\julia\stdlib\v1.11\Pkg\src\Operations.jl:1172
#
#  [12] build_versions
#
#     @ C:\Users\Siergej Sobolewski\AppData\Local\Programs\Julia-1.11.3\share\julia\stdlib\v1.11\Pkg\src\Operations.jl:1090 [inlined]
#
#  [13] add(ctx::Pkg.Types.Context, pkgs::Vector{Pkg.Types.PackageSpec}, new_git::Set{Base.UUID}; allow_autoprecomp::Bool, preserve::Pkg.Types.PreserveLevel, platform::Base.BinaryPlatforms.Platform, target::Symbol)
#
#     @ Pkg.Operations C:\Users\Siergej Sobolewski\AppData\Local\Programs\Julia-1.11.3\share\julia\stdlib\v1.11\Pkg\src\Operations.jl:1468
#
#  [14] add
#
#     @ C:\Users\Siergej Sobolewski\AppData\Local\Programs\Julia-1.11.3\share\julia\stdlib\v1.11\Pkg\src\Operations.jl:1414 [inlined]
#
#  [15] add(ctx::Pkg.Types.Context, pkgs::Vector{Pkg.Types.PackageSpec}; preserve::Pkg.Types.PreserveLevel, platform::Base.BinaryPlatforms.Platform, target::Symbol, allow_autoprecomp::Bool, kwargs::@Kwargs{io::IOContext{IO}})
#
#     @ Pkg.API C:\Users\Siergej Sobolewski\AppData\Local\Programs\Julia-1.11.3\share\julia\stdlib\v1.11\Pkg\src\API.jl:312
#
#  [16] add(pkgs::Vector{Pkg.Types.PackageSpec}; io::IOContext{IO}, kwargs::@Kwargs{})
#
#     @ Pkg.API C:\Users\Siergej Sobolewski\AppData\Local\Programs\Julia-1.11.3\share\julia\stdlib\v1.11\Pkg\src\API.jl:159
#
#  [17] add(pkgs::Vector{Pkg.Types.PackageSpec})
#
#     @ Pkg.API C:\Users\Siergej Sobolewski\AppData\Local\Programs\Julia-1.11.3\share\julia\stdlib\v1.11\Pkg\src\API.jl:148
#
#  [18] add
#
#     @ C:\Users\Siergej Sobolewski\AppData\Local\Programs\Julia-1.11.3\share\julia\stdlib\v1.11\Pkg\src\API.jl:147 [inlined]
#
#  [19] add(pkg::String)
#
#     @ Pkg.API C:\Users\Siergej Sobolewski\AppData\Local\Programs\Julia-1.11.3\share\julia\stdlib\v1.11\Pkg\src\API.jl:146
#
#  [20] top-level scope
#
#     @ c:\Users\Siergej Sobolewski\Kursy Cartesian School\Julia\Introduction-to-Julia-main\Introduction-to-Julia-main\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X55sZmlsZQ==.jl:2

# %% [markdown]
# ✅ Этот метод полезен, если вам нужно автоматически устанавливать зависимости в коде.

# %% [markdown]
# <br>
#
# #### 📌 Использование установленного пакета
#
# После установки пакета его можно подключить в коде с помощью `using` или `import`:

# %%
using Plots

# %% [markdown]
# **или**

# %%
import Plots

# %% [markdown]
# 💡 Разница в том, что `using` автоматически загружает все экспортированные функции пакета, а `import` требует явного указания используемых функций.
#
# <br>

# %% [markdown]
# #### 📌 Обновление пакетов
#
# Чтобы обновить установленные пакеты до актуальной версии, используйте команду:
#
# ```sh
# julia> ]
#
# (@v1.11) pkg> update
# ```

# %% [markdown]
# **Либо в коде:**

# %%
using Pkg
Pkg.update()

# %% [markdown]
# ✅ **Можно обновить конкретный пакет:**

# %% [markdown]
# ```sh
# julia> ]
#
# (@v1.11) pkg> update Plots
# ```

# %% [markdown]
# <br>
#
#
# #### 📌 Удаление пакетов
#
# Если вам больше не нужен пакет, его можно удалить:
#
# ```sh
# julia> ]
#
# (@v1.11) pkg>  remove Plots
# ```
#
# <br>
#
# **Или в коде:**

# %%
using Pkg
Pkg.rm("Plots")
# Out:
#     Updating `C:\Users\Siergej Sobolewski\Kursy Cartesian School\Julia\Introduction-to-Julia-main\Introduction-to-Julia-main\Project.toml`
#   [91a5bcdd] - Plots v1.40.9
#     Updating `C:\Users\Siergej Sobolewski\Kursy Cartesian School\Julia\Introduction-to-Julia-main\Introduction-to-Julia-main\Manifest.toml`
#   [d1d4a3ce] - BitFlags v0.1.9
#   [944b1d66] - CodecZlib v0.7.8
#   [f0e56b4a] - ConcurrentUtilities v2.5.0
#   [8bb1440f] - DelimitedFiles v1.9.1
#   [460bff9d] - ExceptionUnwrapping v0.1.11
#   [c87230d0] - FFMPEG v0.4.2
#   [1fa38f19] - Format v1.3.7
#   [28b8d3ca] - GR v0.73.13
#   [42e2da0e] - Grisu v1.0.2
#   [cd3eb016] - HTTP v1.10.15
#   [1019f520] - JLFzf v0.1.9
#   [692b3bcd] - JLLWrappers v1.7.0
#   [b964fa9f] - LaTeXStrings v1.4.0
#   [23fbe1c1] - Latexify v0.16.6
#   [e6f89c97] - LoggingExtras v1.1.0
#   [739be429] - MbedTLS v1.1.9
#   [442fdcdd] - Measures v0.3.2
#   [4d8831e6] - OpenSSL v1.4.3
#   [b98c9c47] - Pipe v1.3.0
#   [ccf2f8ad] - PlotThemes v3.3.0
#   [995b91a9] - PlotUtils v1.4.3
#   [91a5bcdd] - Plots v1.40.9
#   [3cdcf5f2] - RecipesBase v1.3.4
#   [01d81517] - RecipesPipeline v0.6.12
#   [05181044] - RelocatableFolders v1.0.1
#   [6c6a2e73] - Scratch v1.2.1
#   [992d4aef] - Showoff v1.0.3
#   [777ac1f9] - SimpleBufferStream v1.2.0
#   [860ef19b] - StableRNGs v1.0.2
#   [3bb67fe8] - TranscodingStreams v0.11.3
#   [5c2747f8] - URIs v1.5.1
#   [1cfade01] - UnicodeFun v0.4.1
#   [1986cc42] - Unitful v1.22.0
#   [45397f5d] - UnitfulLatexify v1.6.4
#   [41fe7b60] - Unzip v0.2.0
#   [6e34b625] - Bzip2_jll v1.0.9+0
#   [83423d85] - Cairo_jll v1.18.2+1
#   [ee1fde0b] - Dbus_jll v1.14.10+0
#   [2702e6a9] - EpollShim_jll v0.0.20230411+1
#   [2e619515] - Expat_jll v2.6.5+0
#   [b22a6f82] - FFMPEG_jll v4.4.4+1
#   [a3f928ae] - Fontconfig_jll v2.15.0+0
#   [d7e528f0] - FreeType2_jll v2.13.3+1
#   [559328eb] - FriBidi_jll v1.0.16+0
#   [0656b61e] - GLFW_jll v3.4.0+2
#   [d2c73de3] - GR_jll v0.73.13+0
#   [78b55507] - Gettext_jll v0.21.0+0
#   [7746bdde] - Glib_jll v2.82.4+0
#   [3b182d85] - Graphite2_jll v1.3.14+1
#   [2e76f6c2] - HarfBuzz_jll v8.5.0+0
#   [aacddb02] - JpegTurbo_jll v3.1.1+0
#   [c1c5ebd0] - LAME_jll v3.100.2+0
#   [88015f11] - LERC_jll v4.0.1+0
#   [1d63c593] - LLVMOpenMP_jll v18.1.7+0
#   [dd4b983a] - LZO_jll v2.10.3+0
#   [e9f186c6] - Libffi_jll v3.2.2+2
#   [d4300ac3] - Libgcrypt_jll v1.11.0+0
#   [7e76a0d4] - Libglvnd_jll v1.7.0+0
#   [7add5ba3] - Libgpg_error_jll v1.51.1+0
#   [94ce4f54] - Libiconv_jll v1.18.0+0
#   [4b2f31a3] - Libmount_jll v2.40.3+0
#   [89763e89] - Libtiff_jll v4.7.1+0
#   [38a345b3] - Libuuid_jll v2.40.3+0
#   [e7412a2a] - Ogg_jll v1.3.5+1
#   [458c3c95] - OpenSSL_jll v3.0.16+0
#   [91d4177d] - Opus_jll v1.3.3+0
#   [36c8627f] - Pango_jll v1.56.1+0
#   [30392449] - Pixman_jll v0.43.4+0
#   [c0090381] - Qt6Base_jll v6.7.1+1
#   [629bc702] - Qt6Declarative_jll v6.7.1+2
#   [ce943373] - Qt6ShaderTools_jll v6.7.1+1
#   [e99dba38] - Qt6Wayland_jll v6.7.1+1
#   [a44049a8] - Vulkan_Loader_jll v1.3.243+0
#   [a2964d1f] - Wayland_jll v1.21.0+2
#   [2381bf8a] - Wayland_protocols_jll v1.36.0+0
#   [02c8fc9c] - XML2_jll v2.13.6+1
#   [aed1982a] - XSLT_jll v1.1.42+0
#   [ffd25f8a] - XZ_jll v5.6.4+1
#   [f67eecfb] - Xorg_libICE_jll v1.1.1+0
#   [c834827a] - Xorg_libSM_jll v1.2.4+0
#   [4f6342f7] - Xorg_libX11_jll v1.8.6+3
#   [0c0b7dd1] - Xorg_libXau_jll v1.0.12+0
#   [935fb764] - Xorg_libXcursor_jll v1.2.3+0
#   [a3789734] - Xorg_libXdmcp_jll v1.1.5+0
#   [1082639a] - Xorg_libXext_jll v1.3.6+3
#   [d091e8ba] - Xorg_libXfixes_jll v6.0.0+0
#   [a51aa0fd] - Xorg_libXi_jll v1.8.2+0
#   [d1454406] - Xorg_libXinerama_jll v1.1.5+0
#   [ec84b674] - Xorg_libXrandr_jll v1.5.4+0
#   [ea2f1a96] - Xorg_libXrender_jll v0.9.11+1
#   [14d82f49] - Xorg_libpthread_stubs_jll v0.1.2+0
#   [c7cfdc94] - Xorg_libxcb_jll v1.17.0+3
#   [cc61e674] - Xorg_libxkbfile_jll v1.1.2+1
#   [e920d4aa] - Xorg_xcb_util_cursor_jll v0.1.4+0
#   [12413925] - Xorg_xcb_util_image_jll v0.4.0+1
#   [2def613f] - Xorg_xcb_util_jll v0.4.0+1
#   [975044d2] - Xorg_xcb_util_keysyms_jll v0.4.0+1
#   [0d47668e] - Xorg_xcb_util_renderutil_jll v0.3.9+1
#   [c22f9ab0] - Xorg_xcb_util_wm_jll v0.4.1+1
#   [35661453] - Xorg_xkbcomp_jll v1.4.6+1
#   [33bec58e] - Xorg_xkeyboard_config_jll v2.39.0+0
#   [c5fb5394] - Xorg_xtrans_jll v1.5.1+0
#   [3161d3a3] - Zstd_jll v1.5.7+1
#   [35ca27e7] - eudev_jll v3.2.9+0
#   [214eeab7] - fzf_jll v0.56.3+0
#   [1a1c6b14] - gperf_jll v3.1.1+1
#   [a4ae2306] - libaom_jll v3.11.0+0
#   [0ac62f75] - libass_jll v0.15.2+0
#   [1183f4f0] - libdecor_jll v0.2.2+0
#   [2db6ffa8] - libevdev_jll v1.11.0+0
#   [f638f0a6] - libfdk_aac_jll v2.0.3+0
#   [36db933b] - libinput_jll v1.18.0+0
#   [b53b4c65] - libpng_jll v1.6.46+0
#   [f27f6e37] - libvorbis_jll v1.3.7+2
#   [009596ad] - mtdev_jll v1.1.6+0
#   [1270edf5] - x264_jll v2021.5.5+0
#   [dfaa095f] - x265_jll v3.5.0+0
#   [d8fb68d0] - xkbcommon_jll v1.4.1+2
#   [44cfe95a] - Pkg v1.11.0
#   [3fa0cd96] - REPL v1.11.0
#   [6462fe0b] - Sockets v1.11.0
#   [f489334b] - StyledStrings v1.11.0
#   [a4e569a6] - Tar v1.10.0
#   [8dfed614] - Test v1.11.0
#   [efcefdf7] - PCRE2_jll v10.42.0+1
#   [3f19e933] - p7zip_jll v17.4.0+2

# %% [markdown]
# <br>
#
# ---
#
# <br>
#
# ### **4️⃣  Управление зависимостями и виртуальным окружением в Julia.**
#
# Julia использует механизм **виртуальных окружений** `virtual enveroment` , позволяя каждому проекту иметь свой собственный список зависимостей.
#
# <br>

# %% [markdown]
# #### **1. Создание виртуального окружения и файла файл `Project.toml` .**
#
# Чтобы создать новое окружение, перейдите в каталог вашего проекта и выполните:

# %% [markdown]
# ```sh
# julia> ]
#
# (@v1.11) pkg> activate .
#
# ```
#
# Этим мы **активируем (или создадим) виртуальное окружение** в текущем каталоге, если оно еще не существует.
#
# В результате в каталоге проекта будет автоматически создан файл **`Project.toml`**, который будет хранить список зависимостей.
#
# ##### Пример содержания `Project.toml`:
#
# После установки пакетов, файл `Project.toml` может выглядеть так:
#
# ```sh
# [deps]
# DataFrames = "a93c6f00-e57d-5684-b7b6-d8193f3e46c0"
# Plots = "91a5bcdd-55d7-5caf-9e0b-520d859cae80"
# CSV = "336ed68f-0bac-5ca0-87d4-7b16caf5d00b"
#
# ```
#
# - `deps` — это список зависимостей.
# - Идентификаторы (UUID) соответствуют конкретным пакетам Julia.
# - Версии пакетов хранятся в `Manifest.toml`, если он создан.
#
# <br>
#
# ✅  Команда `activate .` создает `Project.toml`, если он отсутствует, и позволяет управлять зависимостями проекта изолированно от глобальной среды.

# %% [markdown]
# <br>
#
# #### **2. Файл `Manifest.toml` в Julia.**

# %% [markdown]
# Файл **`Manifest.toml`** в Julia создается автоматически, когда в активированном окружении устанавливается хотя бы один пакет, т.е. будет создан автоиатически, как только вы установите первый пакет.
#
# **`Manifest.toml`** содержит полную информацию о зависимостях, включая их версии, зависимости второго уровня (транзитивные зависимости), а также хэш-суммы.
#
# <br>
#
# ##### 🔹 Когда создается `Manifest.toml`?
#
# - Файл `Manifest.toml` **создается автоматически**, если он отсутствует, когда вы добавляете первый пакет в окружение с помощью `Pkg.add()`.
#
# - Если `Manifest.toml` уже существует, он обновляется при установке или обновлении пакетов.
#
# <br>
#
# ##### 🔹 Как создать `Manifest.toml` вручную?
#
# 1. **Активируйте окружение** (если оно еще не активировано):
#    ```sh
#    julia> ]
#    (@v1.11) pkg> activate .
#    ```
#
# 2. **Добавьте хотя бы один пакет**:
#    ```sh
#    (@v1.11) pkg> add DataFrames
#    ```
#    Это создаст **`Manifest.toml`** в текущем каталоге.
#
# 3. **Проверить наличие файлов `Project.toml` и `Manifest.toml`**:
#    ```sh
#    ls
#
#    ```
#
#    Вы должны увидеть в текущем каталоге файлы:
#    ```
#    Project.toml
#    Manifest.toml
#
#    ```
#
# ##### 🔹 Пример содержимого `Manifest.toml`:
#
# Файл `Manifest.toml` фиксирует точные версии зависимостей:
#
# ```sh
# [[DataFrames]]
# git-tree-sha1 = "b3d5f3..."
# uuid = "a93c6f00-e57d-5684-b7b6-d8193f3e46c0"
# version = "1.3.4"
#
# [[CSV]]
# git-tree-sha1 = "f1a7e8..."
# uuid = "336ed68f-0bac-5ca0-87d4-7b16caf5d00b"
# version = "0.10.2"
#
# [[Tables]]
# deps = ["DataAPI"]
# git-tree-sha1 = "c0e3d9..."
# uuid = "bd369af6-d3d1-50fc-83a0-4a97d4c69242"
# version = "1.7.0"
#
# ```
#
# ##### 🔹 Разница между `Project.toml` и `Manifest.toml`
#
# | Файл            | Описание |
# |----------------|------------|
# | `Project.toml` | Список пакетов, необходимых для проекта (аналог `requirements.txt` в Python). |
# | `Manifest.toml` | Полный список всех зависимостей, включая транзитивные (аналог `poetry.lock` или `package-lock.json`). |
#
# ##### 🔹 Как зафиксировать окружение для репликации?
#
# Чтобы передать окружение другому человеку или запустить на другом компьютере:
#
# 1. Скопируйте `Project.toml` и `Manifest.toml`.
#
# 2. На новой машине выполните:
#
#    ```sh
#    julia> ]
#    (@v1.11) pkg> activate .
#    (@v1.11) pkg> instantiate
#
#    ```
#    Это восстановит все зависимости в точных версиях.
#
# ##### **📌 Важно!**
#
# - **`Manifest.toml` создается при первом `Pkg.add()`**.
#
# - **Он фиксирует точные версии пакетов и их зависимости**.
#
# - **Для полного восстановления окружения используется `Pkg.instantiate()`**.

# %% [markdown]
# <br>
#
# #### **3. Добавление зависимостей в окружение**
#
# После активации окружения добавьте нужные пакеты:
#
# ```sh
# julia> ]
#
# (@v1.11) pkg> add DataFrames CSV
# ```
# <br>
#
# 💡 Теперь все установленные пакеты будут привязаны к этому окружению.
#
# <br>

# %% [markdown]
# ####  **4. Восстановление зависимостей**
#
# Если у вас есть файл `Project.toml` и `Manifest.toml`, можно восстановить окружение:
#
# ```sh
# julia> ]
#
# (@v1.11) pkg> instantiate
# ```
#
#
#
# <br>

# %% [markdown]
# #### **5. Поиск и просмотр пакетов**

# %% [markdown]
# Вы можете искать пакеты в репозитории [https://julialang.org/packages/](https://julialang.org/packages/), либо прямо из Julia:
# ```sh
# julia> ]
#
# (@v1.11) pkg> status  # Покажет установленные пакеты
#
# (@v1.11) pkg> search DataFrames  # Найдет пакеты, связанные с DataFrames
#
# ```
#
# <br>
#
# ---

# %% [markdown]
# ### Выводы:
#
# Менеджер пакетов `Pkg` делает работу с зависимостями в Julia простой и удобной. Основные команды:
#
# - `add` — установка пакетов
#
# - `update` — обновление пакетов
#
# - `remove` — удаление пакетов
#
# - `status` — просмотр установленных пакетов
#
# - `activate` — создание окружения
#
# - `instantiate` — восстановление окружения
#
#
# Дальше мы разберем **популярные пакеты Julia** и их использование! 🚀

# %% [markdown]
# <br>
#
# ---
#
# <br>
#
# ## 🔹 **Упражнения:**

# %% [markdown]
# #### ✅ Задание 7.1
#
# Установите пакет `Colors`

# %%
using Pkg
Pkg.add("Colors")
# Out:
#    Resolving package versions...
#   No Changes to `C:\Users\Siergej Sobolewski\Kursy Cartesian School\Julia\Introduction-to-Julia-main\Introduction-to-Julia-main\Project.toml`
#   No Changes to `C:\Users\Siergej Sobolewski\Kursy Cartesian School\Julia\Introduction-to-Julia-main\Introduction-to-Julia-main\Manifest.toml`
# Precompiling project...
#    2964.6 ms  ✓ Contour
#    3747.7 ms  ✓ Example
#     747.9 ms  ✓ StaticArraysCore
#    1067.1 ms  ✓ VersionParsing
#    6254.3 ms  ✓ MacroTools
#    2726.8 ms  ✓ BenchmarkTools
#    1846.0 ms  ✓ Conda
#            ✗ PyCall
#   12235.3 ms  ✓ StaticArrays
#    1472.1 ms  ✓ StaticArrays → StaticArraysStatisticsExt
#    6515.4 ms  ✓ MarchingCubes
#   85462.1 ms  ✓ UnicodePlots
#   11 dependencies successfully precompiled in 117 seconds. 58 already precompiled.
#
# The following 1 direct dependency failed to precompile:
#
# PyCall
#
# Failed to precompile PyCall [438e738f-606a-5dbb-bf0a-cddfbfd45ab0] to "C:\\Users\\Siergej Sobolewski\\.julia\\compiled\\v1.11\\PyCall\\jl_DB3D.tmp".
# ERROR: LoadError: PyCall not properly installed. Please run Pkg.build("PyCall")
# Stacktrace:
#  [1] error(s::String)
#    @ Base .\error.jl:35
#  [2] top-level scope
#    @ C:\Users\Siergej Sobolewski\.julia\packages\PyCall\1gn3u\src\startup.jl:44
#  [3] include(mod::Module, _path::String)
#    @ Base .\Base.jl:557
#  [4] include(x::String)
#    @ PyCall C:\Users\Siergej Sobolewski\.julia\packages\PyCall\1gn3u\src\PyCall.jl:1
#  [5] top-level scope
#    @ C:\Users\Siergej Sobolewski\.julia\packages\PyCall\1gn3u\src\PyCall.jl:38
#  [6] include
#    @ .\Base.jl:557 [inlined]
#  [7] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::Nothing)
#    @ Base .\loading.jl:2881
#  [8] top-level scope
#    @ stdin:6
# in expression starting at C:\Users\Siergej Sobolewski\.julia\packages\PyCall\1gn3u\src\startup.jl:41
# in expression starting at C:\Users\Siergej Sobolewski\.julia\packages\PyCall\1gn3u\src\PyCall.jl:1
# in expression starting at stdin:

# %% [markdown]
# **Давайте создадим палитру из 100 разных цветов:**

# %%
palette = distinguishable_colors(100)
# Out:
# 100-element Vector{RGB{FixedPointNumbers.N0f8}}:
#  RGB(0.0, 0.0, 0.0)
#  RGB(1.0, 1.0, 0.455)
#  RGB(1.0, 0.608, 1.0)
#  RGB(0.0, 0.827, 1.0)
#  RGB(0.886, 0.388, 0.051)
#  RGB(0.0, 0.494, 0.0)
#  RGB(0.0, 0.314, 0.902)
#  RGB(0.675, 0.0, 0.278)
#  RGB(0.0, 1.0, 0.784)
#  RGB(0.0, 0.392, 0.408)
#  ⋮
#  RGB(0.714, 0.976, 0.851)
#  RGB(0.855, 0.0, 0.247)
#  RGB(0.18, 0.129, 0.141)
#  RGB(0.0, 0.345, 0.082)
#  RGB(1.0, 0.557, 0.114)
#  RGB(0.4, 0.455, 0.694)
#  RGB(0.0, 0.804, 0.678)
#  RGB(0.0, 0.498, 0.388)
#  RGB(0.6, 0.435, 0.239)

# %% [markdown]
# **и затем мы можем создать случайно-клетчатую матрицу 3x3 с помощью команды `rand` :**

# %%
rand(palette, 3, 3)
# Out:
# 3×3 Matrix{RGB{FixedPointNumbers.N0f8}}:
#  RGB(0.18, 0.129, 0.141)  RGB(0.0, 0.176, 0.188)    RGB(0.38, 0.11, 0.0)
#  RGB(1.0, 0.737, 0.502)   RGB(0.522, 0.247, 0.204)  RGB(0.769, 0.0, 0.0)
#  RGB(0.78, 0.573, 0.325)  RGB(0.404, 0.31, 0.259)   RGB(0.659, 0.569, 0.812)

# %% [markdown]
# **В следующем блокноте мы будем использовать новый пакет для построения графиков наборов данных.**
